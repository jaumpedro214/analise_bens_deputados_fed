# %% [markdown]
# # Testing Apache Spark queries

# %% [markdown]
# Disclaimer: O intuito deste trabalho é meramente aprender a utilizar o Apache Spark. Embora os dados utilizados tenham teor político, não há intenção de fazer qualquer tipo apologia, seja positiva ou negativa, a qualquer partido ou candidato.
#
# O autor do trabalho declara não ter vínculo algum com nenhum partido político ou candidato.
#
# Com intuito de negar quaisquer questionamentos, tentarei usar algumas estratégias:
# - Sempre utilizar funções aleatórias para printar os dados
# - Tentar trabalhar o problema de forma geral, sem focar em nenhum partido ou candidato
# - Evitar apresentar nomes de candidatos ao menos que seja necessário

# %% [markdown]
# ## Instantiating Spark session

# %%
from pyspark.sql import SparkSession
from pyspark.sql import functions as F

from pyspark.sql.types import (
    StructType, 
    StructField, 
    StringType, 
    IntegerType, 
    DateType,
    FloatType
)

# %%
spark = SparkSession.builder.appName("Test_queries").getOrCreate()
# Out:
# /home/joaopedro/.local/lib/python3.6/site-packages/pyspark/context.py:238: FutureWarning: Python 3.6 support is deprecated in Spark 3.2.
#   FutureWarning

# %% [markdown]
# ## Loading csv files from the folder

# %% [markdown]
# Bens declarados dos Candidatos: https://dados.gov.br/dataset/candidatos-2022
#
# Brasil states: https://github.com/fititnt/gis-dataset-brasil

# %% [markdown]
# ### Loading bens

# %%
df_bens_raw = (
    spark
    .read
    .option("header", "true")
    .option("encoding", 'latin1')
    .option("delimiter", ";")
    .option("inferSchema", "true")
    .csv('./bem_candidato_2022/bem_candidato_2022_BRASIL.csv')
)

# %% [markdown]
# Filtrando as colunas usadas e transformando o valor do bem em float

# %%
df_bens = (
    df_bens_raw
    .select(
        [
            "SQ_CANDIDATO",
            "DS_TIPO_BEM_CANDIDATO",
            "DS_BEM_CANDIDATO",
            "VR_BEM_CANDIDATO"
        ]
    )
    .withColumn(
        'VR_BEM_CANDIDATO',
        F.regexp_replace('VR_BEM_CANDIDATO', ',', '.')
        .cast(FloatType())
    )
)

# %%
df_bens.show(5)
# Out:
# +------------+---------------------+--------------------+----------------+
# |SQ_CANDIDATO|DS_TIPO_BEM_CANDIDATO|    DS_BEM_CANDIDATO|VR_BEM_CANDIDATO|
# +------------+---------------------+--------------------+----------------+
# |110001608768| Veículo automotor...|               Carro|         40000.0|
# |200001608811| Fundos: Ações, Mú...|5.617,50 AÇÕES DA...|        50164.28|
# |240001614377|              Terreno|TERRENO URBANO,  ...|        186200.0|
# |240001614377| Caderneta de poup...|CADERNETA DE POUP...|         2367.39|
# |210001647159| Depósito bancário...|SALDO APLICACAO F...|        22713.17|
# +------------+---------------------+--------------------+----------------+
# only showing top 5 rows

# %% [markdown]
# ### Loading Candidatos

# %%
df_candidatos_raw = (
    spark
    .read
    .option("header", "true")
    .option("encoding", 'latin1')
    .option("delimiter", ";")
    .option("inferSchema", "true")
    .csv('./consulta_cand_2022/consulta_cand_2022_BRASIL.csv')
)

# %%
df_deputados_fed = (
    df_candidatos_raw
    .filter(df_candidatos_raw['DS_SITUACAO_CANDIDATURA'] != 'INAPTO')
    .filter(df_candidatos_raw['CD_CARGO'] == '6') # Código do cargo de deputado federal
    .select(
        [
            "SG_UE",
            "NM_UE",
            "SQ_CANDIDATO",
            "NM_CANDIDATO",
            "SG_PARTIDO",
        ]
    )
)

# %% [markdown]
# Visualizando os dados ...

# %%
(
    df_deputados_fed
    .select( ["SG_UE", "SG_PARTIDO"] )
    .sample(False, 0.01)
    .show(10)
)
# Out:
# +-----+------------+
# |SG_UE|  SG_PARTIDO|
# +-----+------------+
# |   SC|         PSB|
# |   SP|        PRTB|
# |   MA|          DC|
# |   MG|         MDB|
# |   RN|         PSD|
# |   PE|         PDT|
# |   SP|REPUBLICANOS|
# |   SP|         PTB|
# |   RJ|          PP|
# |   RJ|        AGIR|
# +-----+------------+
# only showing top 10 rows

# %% [markdown]
# ## Realizando o Join entre os dois DataFrames

# %% [markdown]
# Unir as duas tabelas usando o campo `SQ_CANDIDATO` como chave

# %%
df_candidatos_bens = (
    df_deputados_fed
    .join(
        df_bens, 
        on='SQ_CANDIDATO', 
        how='left'
    )
)

# %%
df_candidatos_bens.sample(False, 0.01).show(5)
# Out:
# +------------+-----+--------------+--------------------+------------+---------------------+--------------------+----------------+
# |SQ_CANDIDATO|SG_UE|         NM_UE|        NM_CANDIDATO|  SG_PARTIDO|DS_TIPO_BEM_CANDIDATO|    DS_BEM_CANDIDATO|VR_BEM_CANDIDATO|
# +------------+-----+--------------+--------------------+------------+---------------------+--------------------+----------------+
# |160001654829|   PR|        PARANÁ|EDUARDO PINHEIRO ...|        PODE| Caderneta de poup...|POUPANÇA NO BANCO...|          4000.0|
# |160001654829|   PR|        PARANÁ|EDUARDO PINHEIRO ...|        PODE| Veículo automotor...|VEICULO PALIO FIR...|         25000.0|
# |190001609750|   RJ|RIO DE JANEIRO|DERCILEI FRANÇA L...|      AVANTE| Quotas ou quinhõe...|empresa Ki Delíci...|             0.0|
# |160001621906|   PR|        PARANÁ|ANA FÁBIA RIBAS D...|        PROS| Ações (inclusive ...|40 ACOES ON DO MA...|          1280.0|
# |130001619746|   MG|  MINAS GERAIS|BRAZ FERNANDO DA ...|REPUBLICANOS|                 Loja|           comercial|        200000.0|
# +------------+-----+--------------+--------------------+------------+---------------------+--------------------+----------------+
# only showing top 5 rows

# %% [markdown]
# # Queries

# %% [markdown]
# Existem duas formas principais de realizar queries no apache Spark aqui no Python: Funcional e via SQL.
# Essa diferença é meramente de sintaxe e escolha pessoal, pois o Spark executa as queries da mesma forma.
#
# Como eu tenho mais familiaridade com o Pandas, para mim, é mais natural utilizar o encadeamento de funções.

# %% [markdown]
# **Top 10 candidatos a Deputado Federal com maior patrimônio**

# %%
# Nomes e patrimonio dos Candidatos mais ricos
patrimonio_candidatos = (
    df_candidatos_bens
    .groupBy("SQ_CANDIDATO")
    .agg(
        F.sum("VR_BEM_CANDIDATO").alias("VR_BEM_CANDIDATO")
    )
    .join(
        df_deputados_fed,
        on='SQ_CANDIDATO',
        how='left'
    )
    .orderBy(
        F.desc("VR_BEM_CANDIDATO")
    )
    .select(
        [
            "NM_CANDIDATO",
            "SG_PARTIDO",
            "SG_UE",
            "VR_BEM_CANDIDATO",
        ]
    )
    .withColumn(
        "VR_BEM_CANDIDATO",
        F.format_number(
            F.col("VR_BEM_CANDIDATO") / 1e6, 2
        )
    )
)

patrimonio_candidatos.show(10, truncate=False)
# Out:
# +----------------------------------+----------+-----+----------------+
# |NM_CANDIDATO                      |SG_PARTIDO|SG_UE|VR_BEM_CANDIDATO|
# +----------------------------------+----------+-----+----------------+
# |EUNÍCIO LOPES DE OLIVEIRA         |MDB       |CE   |158.18          |
# |RUY ADRIANO BORGES MUNIZ          |AVANTE    |MG   |158.02          |
# |JOSE GOMES FERREIRA FILHO         |PP        |DF   |128.64          |
# |JADYEL SILVA ALENCAR              |PV        |PI   |107.55          |
# |PABLO HENRIQUE COSTA MARÇAL       |PROS      |SP   |88.44           |
# |ALEX DOS SANTOS GARCIA            |PSC       |RN   |80.01           |
# |ADRIANA MANGABEIRA WANDERLEY      |PSD       |DF   |77.06           |
# |NEWTON BONIN                      |UNIÃO     |PR   |76.12           |
# |HERCILIO ARAUJO DINIZ FILHO       |MDB       |MG   |65.90           |
# |PAULO ROBERTO ROQUE ANTONIO KHOURI|NOVO      |DF   |65.29           |
# +----------------------------------+----------+-----+----------------+
# only showing top 10 rows

# %% [markdown]
# **Valor total declarado**

# %%
(
    df_candidatos_bens
    .agg(
        F.sum("VR_BEM_CANDIDATO").alias("TOTAL_BEM_CANDIDATO_BILHOES"),
        F.countDistinct("SQ_CANDIDATO").alias("TOTAL_CANDIDATOS")
    )
    .withColumn(
        "TOTAL_BEM_CANDIDATO_BILHOES",
        F.format_number(
            F.col("TOTAL_BEM_CANDIDATO_BILHOES") / 1e9, 2
        )
    )
    .show()
)
# Out:
# +---------------------------+----------------+
# |TOTAL_BEM_CANDIDATO_BILHOES|TOTAL_CANDIDATOS|
# +---------------------------+----------------+
# |                       7.21|            9823|
# +---------------------------+----------------+

# %% [markdown]
# **Valor total declarado de bens por UF**

# %%
valor_por_uf = (
    df_candidatos_bens
    .groupBy(
        "SG_UE"
    )
    .agg(
        F.sum( F.col("VR_BEM_CANDIDATO") ).alias("TOTAL BENS")
    )
    .orderBy(
        F.desc("TOTAL BENS")
    )
    .toPandas()
)

# %%
valor_por_uf
# Out:
#    SG_UE    TOTAL BENS
# 0     SP  1.214328e+09
# 1     MG  9.504192e+08
# 2     RJ  5.998792e+08
# 3     PR  4.687365e+08
# 4     DF  4.338724e+08
# 5     GO  3.126668e+08
# 6     CE  2.976541e+08
# 7     BA  2.840690e+08
# 8     RS  2.650317e+08
# 9     SC  2.417713e+08
# 10    MA  2.049478e+08
# 11    PE  2.028025e+08
# 12    PA  2.005522e+08
# 13    MT  1.999481e+08
# 14    RR  1.793602e+08
# 15    PI  1.626300e+08
# 16    RN  1.532252e+08
# 17    AC  1.249151e+08
# 18    ES  1.223241e+08
# 19    TO  1.078568e+08
# 20    MS  1.042692e+08
# 21    RO  7.584124e+07
# 22    PB  6.894666e+07
# 23    AL  6.780418e+07
# 24    AM  5.897767e+07
# 25    SE  5.343360e+07
# 26    AP  4.920965e+07

# %% [markdown]
# **Valor total declarado de bens por Tipo de bem**

# %%
from pyspark.sql.window import Window

# %%
valor_por_tipo_bem = (
    df_candidatos_bens
    .groupBy(
        "DS_TIPO_BEM_CANDIDATO"
    )
    .agg(
        F.sum( F.col("VR_BEM_CANDIDATO") ).alias("TOTAL BENS")
    )
    .orderBy(
        F.desc("TOTAL BENS")
    )
    .withColumn(
        "Percentual",
        # Trick to get the percentage of each row
        # https://stackoverflow.com/questions/48915834/how-to-calculate-percentage-of-each-row-in-pyspark
        F.col("TOTAL BENS") / F.sum(F.col("TOTAL BENS")).over(Window.partitionBy()) * 100
    )
    .toPandas()
)

# %%
valor_por_tipo_bem
# Out:
#                                 DS_TIPO_BEM_CANDIDATO    TOTAL BENS  \
# 0                                                Casa  1.058904e+09
# 1                       Quotas ou quinhões de capital  9.503186e+08
# 2                                         Apartamento  8.900710e+08
# 3                                 Outros bens imóveis  6.791680e+08
# 4                              OUTROS BENS E DIREITOS  5.823553e+08
# 5                                             Terreno  5.213774e+08
# 6                    Outras participações societárias  4.374761e+08
# 7   Veículo automotor terrestre: caminhão, automóv...  3.962000e+08
# 8         Aplicação de renda fixa (CDB, RDB e outros)  2.350587e+08
# 9                    Crédito decorrente de empréstimo  1.884130e+08
# 10                  Outras aplicações e Investimentos  1.775297e+08
# 11               Dinheiro em espécie - moeda nacional  1.063355e+08
# 12                                          Terra nua  1.051118e+08
# 13        Depósito bancário em conta corrente no País  9.880261e+07
# 14  Ações (inclusive as provenientes de linha tele...  8.974938e+07
# 15                                   Prédio comercial  7.493611e+07
# 16                                      Outros fundos  7.088304e+07
# 17                                           Aeronave  5.783114e+07
# 18  Fundos: Ações, Mútuos de Privatização, Invest....  5.776914e+07
# 19                                   Sala ou conjunto  5.542519e+07
# 20             VGBL - Vida Gerador de Benefício Livre  5.436807e+07
# 21              Outros créditos e poupança vinculados  4.405579e+07
# 22                                 Outros bens móveis  4.004863e+07
# 23                              Caderneta de poupança  3.424939e+07
# 24                                 Prédio residencial  2.362706e+07
# 25                                         Construção  2.334256e+07
# 26                                             Galpão  2.069504e+07
# 27                                               Loja  1.985829e+07
# 28    Depósito bancário em conta corrente no exterior  1.827337e+07
# 29                          Consórcio não contemplado  1.821366e+07
# 30                    Crédito decorrente de alienação  1.320504e+07
# 31  Fundo de Longo Prazo e Fundo de Investimentos ...  1.272446e+07
# 32                                       Benfeitorias  1.054468e+07
# 33  Jóia, quadro, objeto de arte, de coleção, anti...  7.593033e+06
# 34                  Fundo de Investimento Imobiliário  6.730010e+06
# 35                               Fundo de Curto Prazo  4.166844e+06
# 36  Bem relacionado com o exercício da atividade a...  4.059638e+06
# 37                                         Embarcação  3.872235e+06
# 38                             Ouro, ativo financeiro  3.314514e+06
# 39            Dinheiro em espécie - moeda estrangeira  2.678486e+06
# 40                     Direito de lavra e assemelhado  2.275742e+06
# 41  Poupança para construção ou aquisição de bem i...  1.364517e+06
# 42                      Título de clube e assemelhado  1.109066e+06
# 43               Outros depósitos à vista e numerário  8.443458e+05
# 44            Direito de autor, de inventor e patente  1.815000e+05
# 45                  Plano PAIT e caderneta de pecúlio  1.332178e+05
# 46                                   Linha telefônica  1.128091e+05
# 47               Mercado futuros, de opções e a termo  8.233448e+04
# 48                     Licença e concessões especiais  2.774001e+04
# 49                                            Leasing  4.278930e+03
# 50                                               None           NaN
#
#     Percentual
# 0    14.695832
# 1    13.188846
# 2    12.352709
# 3     9.425725
# 4     8.082125
# 5     7.235853
# 6     6.071442
# 7     5.498598
# 8     3.262225
# 9     2.614860
# 10    2.463817
# 11    1.475760
# 12    1.458777
# 13    1.371216
# 14    1.245572
# 15    1.039989
# 16    0.983739
# 17    0.802600
# 18    0.801740
# 19    0.769210
# 20    0.754539
# 21    0.611421
# 22    0.555809
# 23    0.475325
# 24    0.327904
# 25    0.323956
# 26    0.287213
# 27    0.275600
# 28    0.253604
# 29    0.252775
# 30    0.183264
# 31    0.176594
# 32    0.146343
# 33    0.105379
# 34    0.093401
# 35    0.057829
# 36    0.056341
# 37    0.053740
# 38    0.046000
# 39    0.037173
# 40    0.031584
# 41    0.018937
# 42    0.015392
# 43    0.011718
# 44    0.002519
# 45    0.001849
# 46    0.001566
# 47    0.001143
# 48    0.000385
# 49    0.000059
# 50         NaN
